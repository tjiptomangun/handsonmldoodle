# %%
#https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/

import pandas as pd
import random
import os
UK_PATH = "datasets/uk500"
csv_path = os.path.join(UK_PATH, 'uk-500.csv')

data = pd.read_csv(csv_path)

data['id'] = [random.randint(0, 1000) for x in range(data.shape[0])]

data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  432
# 1     http://www.capgeminiamerica.co.uk  399
# 2      http://www.elliottjohnwesq.co.uk  456
# 3          http://www.mcmahanbenl.co.uk  820
# 4        http://www.champagneroom.co.uk   14

# %%
data.shape
# Out:
# (500, 12)

# %%
data.iloc[0]
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# id                                               432
# Name: 0, dtype: object

# %%
data.iloc[[0]] # first row of data frame
# Out:
#   first_name   last_name             company_name       address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                 city county   postal        phone1        phone2  \
# 0  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                      email                                   web   id
# 0  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk  432

# %%
data.iloc[1] # 2nd row as series
# Out:
# first_name                                   Evan
# last_name                               Zigomalas
# company_name                   Cap Gemini America
# address                               5 Binney St
# city                                   Abbey Ward
# county                            Buckinghamshire
# postal                                   HP11 2AX
# phone1                               01937-864715
# phone2                               01714-737668
# email                    evan.zigomalas@gmail.com
# web             http://www.capgeminiamerica.co.uk
# id                                            399
# Name: 1, dtype: object

# %%
data.iloc[[1]] # 2nd row
# Out:
#   first_name  last_name        company_name      address        city  \
# 1       Evan  Zigomalas  Cap Gemini America  5 Binney St  Abbey Ward
#
#             county    postal        phone1        phone2  \
# 1  Buckinghamshire  HP11 2AX  01937-864715  01714-737668
#
#                       email                                web   id
# 1  evan.zigomalas@gmail.com  http://www.capgeminiamerica.co.uk  399

# %%
data.iloc[[-1]] # last row
# Out:
#     first_name last_name                    company_name          address  \
# 499         Mi    Richan  Nelson Wright Haworth Golf Crs  6 Norwood Grove
#
#                   city        county   postal        phone1        phone2  \
# 499  Tanworth-in-Arden  Warwickshire  B94 5RZ  01451-785624  01202-738406
#
#               email                                          web  id
# 499  mi@hotmail.com  http://www.nelsonwrighthaworthgolfcrs.co.uk  99

# %%
data.iloc[:,0] # first column of dframe
# Out:
# 0          Aleshia
# 1             Evan
# 2           France
# 3          Ulysses
# 4           Tyisha
# 5             Eric
# 6             Marg
# 7          Laquita
# 8             Lura
# 9           Yuette
# 10        Fernanda
# 11     Charlesetta
# 12        Corrinne
# 13          Niesha
# 14          Rueben
# 15         Michell
# 16           Edgar
# 17          Dewitt
# 18        Charisse
# 19             Mee
# 20           Peter
# 21         Octavio
# 22          Martha
# 23         Tamesha
# 24            Tess
# 25         Leonard
# 26        Svetlana
# 27             Pok
# 28       Augustine
# 29           Karma
#           ...
# 470           Tony
# 471            Val
# 472            Mel
# 473       Isabella
# 474         Erasmo
# 475          Ivory
# 476         Nikita
# 477          Aleta
# 478           Owen
# 479        Pauline
# 480        Tijuana
# 481          Ahmad
# 482         Jamika
# 483        Derrick
# 484     Jacquelyne
# 485        Zachary
# 486         Sophia
# 487       Isabelle
# 488         Ronnie
# 489       Krystina
# 490         Rosita
# 491           Huey
# 492         Elbert
# 493           Pura
# 494         Alesia
# 495          Avery
# 496           Reid
# 497      Charlette
# 498      Celestina
# 499             Mi
# Name: first_name, Length: 500, dtype: object

# %%
data.iloc[[:,0]]
# Out:
#   File "<ipython-input-9-7954e7d9f4ac>", line 1
#     data.iloc[[:,0]]
#                ^
# SyntaxError: invalid syntax

# %%
data.iloc[:,1] # 2nd column

# %%
data.iloc[:,-1] # last column

# %%
# Multiple row and column selection using iloc and DataFrame
data.iloc[0:5] # 1st five rows of dataframe

# %%
data.iloc[:,0:3] # first 3 columns of dataframe with all rows

# %%
data.iloc[[47, 53, 59, 61], [1, 2, 3, 5, 7]]#row 48th, 54rd, 60th 62st columns 2nd 3rd 4th 6th 8th

# %%
data.iloc[0:5, 5:8]

# %%
print(type(data.iloc[0])) #series

# %%
print(type(data.iloc[[0]])) #dataFrame

# %%
print(type(data.iloc[0:1])) #dataFrame

# %%
print(type(data.iloc[0:2])) #dataFrame

# %%
data.set_index("last_name", inplace=False)

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  432
# 1     http://www.capgeminiamerica.co.uk  399
# 2      http://www.elliottjohnwesq.co.uk  456
# 3          http://www.mcmahanbenl.co.uk  820
# 4        http://www.champagneroom.co.uk   14

# %%
#The Pandas loc indexer can be used with DataFrames for two different use cases:

# a.) Selecting rows by label/index
# b.) Selecting rows with a boolean / conditional lookup

data.set_index("last_name", inplace=True)

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  432
# 1     http://www.capgeminiamerica.co.uk  399
# 2      http://www.elliottjohnwesq.co.uk  456
# 3          http://www.mcmahanbenl.co.uk  820
# 4        http://www.champagneroom.co.uk   14

# %%
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# Tomkiewicz  01835-703597  01944-369967     atomkiewicz@hotmail.com
# Zigomalas   01937-864715  01714-737668    evan.zigomalas@gmail.com
# Andrade     01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters   01912-771311  01302-601380         ulysses@hotmail.com
# Veness      01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                              web   id
# last_name
# Tomkiewicz  http://www.alandrosenburgcpapc.co.uk  432
# Zigomalas      http://www.capgeminiamerica.co.uk  399
# Andrade         http://www.elliottjohnwesq.co.uk  456
# Mcwalters           http://www.mcmahanbenl.co.uk  820
# Veness            http://www.champagneroom.co.uk   14

# %%
data.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# id                                           456
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade']]
# Out:
#           first_name         company_name       address  \
# last_name
# Andrade       France  Elliott, John W Esq  8 Moor Place
#
#                                      city       county   postal        phone1  \
# last_name
# Andrade    East Southbourne and Tuckton W  Bournemouth  BH6 3BE  01347-368222
#
#                  phone2                       email  \
# last_name
# Andrade    01935-821636  france.andrade@hotmail.com
#
#                                         web   id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  456

# %%
data.loc['Andrade': 'Veness']
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Mcwalters    Ulysses       Mcmahan, Ben L      505 Exeter Rd
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county    postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth   BH6 3BE
# Mcwalters              Hawerby cum Beesby   Lincolnshire  DN36 5RP
# Veness         Greets Green and Lyng Ward  West Midlands   B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters  01912-771311  01302-601380         ulysses@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web   id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  456
# Mcwalters      http://www.mcmahanbenl.co.uk  820
# Veness       http://www.champagneroom.co.uk   14

# %%
data.loc[['Andrade', 'Veness'], ['first_name','address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc['Andrade': 'Veness', ['first_name','address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Mcwalters    Ulysses      505 Exeter Rd              Hawerby cum Beesby
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc['Andrade': 'Veness', 'city': 'email']
# Out:
#                                      city         county    postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth   BH6 3BE
# Mcwalters              Hawerby cum Beesby   Lincolnshire  DN36 5RP
# Veness         Greets Green and Lyng Ward  West Midlands   B70 9DT
#
#                  phone1        phone2                       email
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters  01912-771311  01302-601380         ulysses@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com

# %%
#  Change the index to be based on the 'id' column
data.set_index('id', inplace=True)

# %%
data.loc[477]
# Out:
# first_name                                        Cheryll
# company_name                   Blaineco Structural Movers
# address                                    666 Moor Place
# city                                   Shepway South Ward
# county                                               Kent
# postal                                           ME15 8ST
# phone1                                       01780-380120
# phone2                                       01494-202350
# email                         cheryll_yurich@yurich.co.uk
# web             http://www.blainecostructuralmovers.co.uk
# Name: 477, dtype: object

# %%
# Boolean / Logical index using loc
data.loc[data['first_name'] == 'Antonio']
# Out:
#     first_name            company_name                address  \
# id
# 250    Antonio        Combs Sheetmetal  353 Standish St #8264
# 568    Antonio  Saint Thomas Creations          425 Howley St
# 832    Antonio    Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# id
# 250  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 568                  Gaer Community        Newport  NP20 3DE  01463-409090
# 832                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                            email  \
# id
# 250  01388-777812     antonio.villamarin@gmail.com
# 568  01242-318420  antonio_glasford@glasford.co.uk
# 832  01442-946357         antonio.heilig@gmail.com
#
#                                        web
# id
# 250       http://www.combssheetmetal.co.uk
# 568  http://www.saintthomascreations.co.uk
# 832    http://www.radissonsuitehotel.co.uk

# %%
data.loc[data['first_name'] == 'Erasmo', ['company_name', 'email', 'phone1']]
# Out:
#            company_name                         email        phone1
# id
# 616  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# 419            Pan Optx             egath@hotmail.com  01445-796544
# 353    Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397
