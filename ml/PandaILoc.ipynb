# %%
#https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/

import pandas as pd
import random
import os
UK_PATH = "datasets/uk500"
csv_path = os.path.join(UK_PATH, 'uk-500.csv')

data = pd.read_csv(csv_path)

data['id'] = [random.randint(0, 1000) for x in range(data.shape[0])]

data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.shape
# Out:
# (500, 12)

# %%
data.iloc[0]
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# id                                               373
# Name: 0, dtype: object

# %%
data.iloc[[0]] # first row of data frame
# Out:
#   first_name   last_name             company_name       address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                 city county   postal        phone1        phone2  \
# 0  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                      email                                   web   id
# 0  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk  373

# %%
data.iloc[1] # 2nd row as series
# Out:
# first_name                                   Evan
# last_name                               Zigomalas
# company_name                   Cap Gemini America
# address                               5 Binney St
# city                                   Abbey Ward
# county                            Buckinghamshire
# postal                                   HP11 2AX
# phone1                               01937-864715
# phone2                               01714-737668
# email                    evan.zigomalas@gmail.com
# web             http://www.capgeminiamerica.co.uk
# id                                            508
# Name: 1, dtype: object

# %%
data.iloc[[1]] # 2nd row
# Out:
#   first_name  last_name        company_name      address        city  \
# 1       Evan  Zigomalas  Cap Gemini America  5 Binney St  Abbey Ward
#
#             county    postal        phone1        phone2  \
# 1  Buckinghamshire  HP11 2AX  01937-864715  01714-737668
#
#                       email                                web   id
# 1  evan.zigomalas@gmail.com  http://www.capgeminiamerica.co.uk  508

# %%
data.iloc[[-1]] # last row
# Out:
#     first_name last_name                    company_name          address  \
# 499         Mi    Richan  Nelson Wright Haworth Golf Crs  6 Norwood Grove
#
#                   city        county   postal        phone1        phone2  \
# 499  Tanworth-in-Arden  Warwickshire  B94 5RZ  01451-785624  01202-738406
#
#               email                                          web   id
# 499  mi@hotmail.com  http://www.nelsonwrighthaworthgolfcrs.co.uk  356

# %%
data.iloc[:,0] # first column of dframe
# Out:
# 0          Aleshia
# 1             Evan
# 2           France
# 3          Ulysses
# 4           Tyisha
# 5             Eric
# 6             Marg
# 7          Laquita
# 8             Lura
# 9           Yuette
# 10        Fernanda
# 11     Charlesetta
# 12        Corrinne
# 13          Niesha
# 14          Rueben
# 15         Michell
# 16           Edgar
# 17          Dewitt
# 18        Charisse
# 19             Mee
# 20           Peter
# 21         Octavio
# 22          Martha
# 23         Tamesha
# 24            Tess
# 25         Leonard
# 26        Svetlana
# 27             Pok
# 28       Augustine
# 29           Karma
#           ...
# 470           Tony
# 471            Val
# 472            Mel
# 473       Isabella
# 474         Erasmo
# 475          Ivory
# 476         Nikita
# 477          Aleta
# 478           Owen
# 479        Pauline
# 480        Tijuana
# 481          Ahmad
# 482         Jamika
# 483        Derrick
# 484     Jacquelyne
# 485        Zachary
# ...

# %%
data.iloc[[:,0]]
# Out:
#   File "<ipython-input-9-7954e7d9f4ac>", line 1
#     data.iloc[[:,0]]
#                ^
# SyntaxError: invalid syntax

# %%
data.iloc[:,1] # 2nd column
# Out:
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
# 5           Rampy
# 6        Grasmick
# 7           Hisaw
# 8        Manzella
# 9          Klapec
# 10         Writer
# 11            Erm
# 12          Jaret
# 13          Bruch
# 14      Gastellum
# 15      Throssell
# 16          Kanne
# 17          Julio
# 18       Spinello
# 19       Lapinski
# 20      Gutierres
# 21      Salvadore
# 22        Teplica
# 23         Veigel
# 24          Sitra
# 25         Kufner
# 26         Tauras
# 27       Molaison
# 28       Growcock
# 29         Quarto
#           ...
# 470    Diazdeleon
# 471        Villot
# 472      Picciuto
# 473    Piatkowski
# 474          Rhea
# 475       Lohrenz
# 476         Walka
# 477        Ligons
# 478       Jentzen
# 479         Fling
# 480      Machalek
# 481       Alsaqri
# 482        Conoly
# 483       Dolloff
# 484       Reibman
# 485    Freeburger
# 486       Gaucher
# 487          Kono
# 488       Brigman
# ...

# %%
data.iloc[:,-1] # last column
# Out:
# 0      373
# 1      508
# 2      650
# 3      647
# 4      531
# 5      273
# 6      970
# 7      627
# 8      699
# 9      252
# 10     296
# 11     199
# 12      64
# 13     446
# 14      82
# 15     619
# 16     663
# 17     281
# 18     562
# 19     164
# 20     898
# 21     819
# 22     153
# 23      95
# 24     778
# 25     247
# 26     550
# 27     101
# 28     971
# 29     139
#       ...
# 470    147
# 471    342
# 472    886
# 473    419
# 474    422
# 475    805
# 476    623
# 477    558
# 478    657
# 479    693
# 480    705
# 481    846
# 482    848
# 483    311
# 484     11
# 485    794
# 486     10
# 487    625
# 488    291
# 489    454
# 490    234
# 491     81
# 492    634
# 493     38
# 494    809
# 495    393
# 496    405
# 497    201
# 498    345
# 499    356
# Name: id, Length: 500, dtype: int64

# %%
# Multiple row and column selection using iloc and DataFrame
data.iloc[0:5] # 1st five rows of dataframe
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.iloc[:,0:3] # first 3 columns of dataframe with all rows
# Out:
#       first_name   last_name                    company_name
# 0        Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1           Evan   Zigomalas              Cap Gemini America
# 2         France     Andrade             Elliott, John W Esq
# 3        Ulysses   Mcwalters                  Mcmahan, Ben L
# 4         Tyisha      Veness                  Champagne Room
# 5           Eric       Rampy         Thompson, Michael C Esq
# 6           Marg    Grasmick   Wrangle Hill Auto Auct & Slvg
# 7        Laquita       Hisaw           In Communications Inc
# 8           Lura    Manzella                 Bizerba Usa Inc
# 9         Yuette      Klapec                       Max Video
# 10      Fernanda      Writer            K & R Associates Inc
# 11   Charlesetta         Erm                Cain, John M Esq
# 12      Corrinne       Jaret               Sound Vision Corp
# 13        Niesha       Bruch          Rowley/hansell Petetin
# ...

# %%
data.iloc[[47, 53, 59, 61], [1, 2, 3, 5, 7]]#row 48th, 54rd, 60th 62st columns 2nd 3rd 4th 6th 8th
# Out:
#     last_name            company_name           address           county  \
# 47   Devereux           Cash 4 Checks  3 North View #35   West Yorkshire
# 53  Klingaman          Welders Supply    67 Micawber St   Greater London
# 59     Chisum  Bohs Well Drilling Inc    662 Grove Park  Nottinghamshire
# 61      Bairo    Reid, Carleton B Esq       3 August Rd           Surrey
#
#           phone1
# 47  01607-269930
# 53  01712-135466
# 59  01835-634521
# 61  01670-813697

# %%
data.iloc[0:5, 5:8]
# Out:
#             county    postal        phone1
# 0             Kent   CT2 7PP  01835-703597
# 1  Buckinghamshire  HP11 2AX  01937-864715
# 2      Bournemouth   BH6 3BE  01347-368222
# 3     Lincolnshire  DN36 5RP  01912-771311
# 4    West Midlands   B70 9DT  01547-429341

# %%
print(type(data.iloc[0])) #series
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(data.iloc[[0]])) #dataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(data.iloc[0:1])) #dataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(data.iloc[0:2])) #dataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.set_index("last_name", inplace=False)
# Out:
#              first_name                    company_name  \
# last_name
# Tomkiewicz      Aleshia         Alan D Rosenburg Cpa Pc
# Zigomalas          Evan              Cap Gemini America
# Andrade          France             Elliott, John W Esq
# Mcwalters       Ulysses                  Mcmahan, Ben L
# Veness           Tyisha                  Champagne Room
# Rampy              Eric         Thompson, Michael C Esq
# Grasmick           Marg   Wrangle Hill Auto Auct & Slvg
# Hisaw           Laquita           In Communications Inc
# Manzella           Lura                 Bizerba Usa Inc
# Klapec           Yuette                       Max Video
# Writer         Fernanda            K & R Associates Inc
# Erm         Charlesetta                Cain, John M Esq
# Jaret          Corrinne               Sound Vision Corp
# Bruch            Niesha          Rowley/hansell Petetin
# Gastellum        Rueben   Industrial Engineering Assocs
# ...

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
#The Pandas loc indexer can be used with DataFrames for two different use cases:

# a.) Selecting rows by label/index
# b.) Selecting rows with a boolean / conditional lookup

data.set_index("last_name", inplace=True)

# %%
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %%
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %%
data.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# id                                           650
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade']]
# Out:
#           first_name         company_name       address  \
# last_name
# Andrade       France  Elliott, John W Esq  8 Moor Place
#
#                                      city       county   postal        phone1  \
# last_name
# Andrade    East Southbourne and Tuckton W  Bournemouth  BH6 3BE  01347-368222
#
#                  phone2                       email  \
# last_name
# Andrade    01935-821636  france.andrade@hotmail.com
#
#                                         web   id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  650

# %%
data.loc['Andrade': 'Veness']
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Mcwalters    Ulysses       Mcmahan, Ben L      505 Exeter Rd
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county    postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth   BH6 3BE
# Mcwalters              Hawerby cum Beesby   Lincolnshire  DN36 5RP
# Veness         Greets Green and Lyng Ward  West Midlands   B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters  01912-771311  01302-601380         ulysses@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web   id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  650
# ...

# %%
data.loc[['Andrade', 'Veness'], ['first_name','address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc['Andrade': 'Veness', ['first_name','address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Mcwalters    Ulysses      505 Exeter Rd              Hawerby cum Beesby
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc['Andrade': 'Veness', 'city': 'email']
# Out:
#                                      city         county    postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth   BH6 3BE
# Mcwalters              Hawerby cum Beesby   Lincolnshire  DN36 5RP
# Veness         Greets Green and Lyng Ward  West Midlands   B70 9DT
#
#                  phone1        phone2                       email
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters  01912-771311  01302-601380         ulysses@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com

# %%
#  Change the index to be based on the 'id' column
data.set_index('id', inplace=True)

# %%
data.loc[477]
# Out:
#     first_name                    company_name            address  \
# id
# 477    Cheryll      Blaineco Structural Movers     666 Moor Place
# 477    Aleisha  Pathe Cmptr Cntrl Systems Corp  341 Birchfield St
#
#                    city  county    postal        phone1        phone2  \
# id
# 477  Shepway South Ward    Kent  ME15 8ST  01780-380120  01494-202350
# 477  Wareham St. Martin  Dorset  BH16 6JJ  01341-997268  01864-899304
#
#                            email                                          web
# id
# 477  cheryll_yurich@yurich.co.uk    http://www.blainecostructuralmovers.co.uk
# 477       aleisha.lemm@gmail.com  http://www.pathecmptrcntrlsystemscorp.co.uk

# %%
# Boolean / Logical index using loc
data.loc[data['first_name'] == 'Antonio']
# Out:
#     first_name            company_name                address  \
# id
# 16     Antonio        Combs Sheetmetal  353 Standish St #8264
# 903    Antonio  Saint Thomas Creations          425 Howley St
# 158    Antonio    Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# id
# 16   Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 903                  Gaer Community        Newport  NP20 3DE  01463-409090
# 158                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                            email  \
# id
# 16   01388-777812     antonio.villamarin@gmail.com
# 903  01242-318420  antonio_glasford@glasford.co.uk
# 158  01442-946357         antonio.heilig@gmail.com
#
#                                        web
# id
# 16        http://www.combssheetmetal.co.uk
# 903  http://www.saintthomascreations.co.uk
# 158    http://www.radissonsuitehotel.co.uk

# %%
data.loc[data['first_name'] == 'Erasmo', ['company_name', 'email', 'phone1']]
# Out:
#            company_name                         email        phone1
# id
# 647  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# 816            Pan Optx             egath@hotmail.com  01445-796544
# 422    Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397
